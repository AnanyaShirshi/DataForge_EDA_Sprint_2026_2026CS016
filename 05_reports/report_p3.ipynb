# %% [markdown]
# #Practical 3 - Interactive Pivot Dashboards
#
# Student ID: 2026CS016
#
# Name: Ananya Shirshi
#
# Dataset:Global_Superstore2
#
# ---
#
# ---
#
# ---
#
#
#
#
#
#
#
# ##Problem Statement:
# Build an interactive dashboard that allows for real-time data exploration. Stakeholders require quick, dynamic summaries of business performance without the complexity of analyzing raw data themselves.
#
#
# ---
#
# ---
#
#
#
#
#
# ##Procedure:
# . IDE Setup: Microsoft Excel.
#
# . Workflow:
#
#   1. Create three different Pivot Tables to summarise Sales by Region, Profit by Category and Orders by Month.
#   2. Generate corresponding Pivot Charts for each of the three tables to provide visual representations.
#   3. Insert two slicers(Year and Country) into the workspace.
#   4. Connect both Slicers to all three Pivot Tables to enable cross dimensional filtering.
#
# ---
#
# ---
#
#
#
#
#
#
# ##Outputs created:
#
# 1. Summary File: pivot_dashboard.xlsx (Uploaded in the next cells.)
# 2. Screenshots: dashboard_preview1.png , dashboard_preview2.png, dashboard_preview3.png
# 3. Report: report_p3.ipynb
#
# ---
#
#
# ---
#
#
#
#
# ##Observations:
#
# Q1. Which pivot table gave the most useful insight?
#
# Ans: The Sales by Region Pivot Table and Chart gave the most useful insight since the data is sparse and give complete idea of which region has the most sales.
#
# ---
#
#
#
# Q2. What changed when you used slicers?
#
# Ans:
# When i used slicers, it allowed me to only view the insights of the particular year and region that i selected without any unnecessary data.
#
#
# ---
#
#
#
# Q3. What is one limitation of doing this only in Excel?
#
# Ans: One limitation of doing data analysis in Excel is:
#
# 1. Excel is not well-suited for handling very large datasets. The workbook becomes slow and difficult to manage making the analysis less efficient.
#
# ---
#
# ---
#
#
#
#
#
# ##Conclusion:
#
#
# Interactive dashboards are essential for business intelligence because they shift the responsibility of analysis from static report generation to self-service exploration, empowering stakeholders to answer their own performance questions.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e88f831c-1fdd-47a3-a60c-2d48688ef024" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e88f831c-1fdd-47a3-a60c-2d48688ef024">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for sheet_name, df in all_sheets.items():
    print(f"\nSheet: {sheet_name}")
    print(df.head())
# Out:
# Sheet: PivotSalesRegion
#    Unnamed: 0    Unnamed: 1
# 0         NaN           NaN
# 1  Row Labels  Sum of Sales
# 2      Africa    783773.211
# 3      Canada      66928.17
# 4   Caribbean  324280.86104
#
# Sheet: PivotProfitCategory
#         Unnamed: 0     Unnamed: 1
# 0              NaN            NaN
# 1       Row Labels  Sum of Profit
# 2        Furniture    285204.7238
# 3  Office Supplies    518473.8343
# 4       Technology   663778.73318
#
# Sheet: PivotMonthOrders
#     Unnamed: 0         Unnamed: 1
# 0          NaN                NaN
# 1   Row Labels  Count of Order ID
# 2   01-09-2011                  2
# 3  Grand Total                  2

# %% [markdown]
# Screenshot 1: Pivot Profit Category.
# ![dasboard_preview2.png](data:image/png;base64,...)
#
# Screenshot 2: Pivot Sales Region
#
# ![dashboard_preview1.png](data:image/png;base64,...)
#
# Screenshot 3: Pivot Month Orders.
#
# ![dashboard_preview3.png](data:image/png;base64,...)
