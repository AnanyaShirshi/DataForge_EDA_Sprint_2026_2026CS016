# %% [markdown]
# #Practical 2 - Descriptive Statistics & Outlier Detection
#
# Student ID: 2026CS016
#
# Name: Ananya Shirshi
#
# Dataset:Global_Superstore2
#
# ---
#
# ---
#
# ---
#
#
#
#
#
#
#
# ##Problem Statement:
# Understand numerical spread of the dataset and identify annomalies. Raw data can contian outliers that skew performance metrics and hide true average behaviour of business.
#
#
# ---
#
# ---
#
#
#
#
#
# ##Procedure:
# . IDE Setup: Microsoft Excel.
#
# . Workflow:
#
#   1. Create a "Stats Summary" sheet within the Excel.
#   2. Calculate key metrics for 'Sales' and 'Profit' columns using the formulas AVERAGE(), MEDIAN(), STDEV.P() and QUARTILE().
#   3. Set custom conditional formatting rules to highlight outliers, specifically targetting negative profit margins.
#   4. Apply conditional formatting to visually distinguish high and low performance range across the datasets.
#   5. Generate statistical table for stakeholder reference.
#   6. Capture screenshots of the formatting and formula results for documentations.
#
# ---
#
# ---
#
#
#
#
#
#
# ##Outputs created:
#
# 1. Summary File: stats_summary.xlsx (Uploaded in the next cells.)
# 2. Screenshots: 02_Output1.png , 02_Output2.png
# 3. Report: report_p2.ipynb
#
# ---
#
#
# ---
#
#
#
#
# ##Observations:
#
# Q1. Which column had the highest data quality risk
#
# Ans: The rows "Sales", "Profit", "Discount", "Shipping Cost" ,"Order Date" and "Ship Date" had the highest data quality risk since Excel had not assumed their data types and there were missing symbols of percentage and currency
#
# ---
#
#
#
# Q2. What cleaning decision did you take and why?
#
# Ans:
# I formatted the columns according to their data types. I also placed percentage sybols for the column "Discount" and currency symbol for the columns "Sales", "Profit" and "Ship Cost".
#
#
# ---
#
#
#
# Q3. Why should raw data and cleaned data be kept separately?
#
# Ans: We must keep Raw Data and Cleaned Data separately because:
#
# 1. To preserve original data.
# 2. Prevent accidental data loss.
# 3. Reproducibility.
# 4. To make debugging easier.
# 5. For multiple analyses.
#
# ---
#
# ---
#
#
#
#
#
# ##Conclusion:
#
#
# Identifying outliers is important before conducting further analysis because statistical models are highly sensitive to extreme values which can lead to misleading conclusions if not properly handled or investigated.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ccd998b-33b0-49aa-937d-951ab761b2be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ccd998b-33b0-49aa-937d-951ab761b2be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel("stats_summary.xlsx")
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# ...

# %% [markdown]
# Screenshot 1: Stats Table
#
# ![02_Output1.png](data:image/png;base64,...)
#
# Screenshot 2: Reffered data
#
# ![02_Output2.png](data:image/png;base64,...)
